# %% [markdown]
# **Business Objective**: Create a data driven strategy for optimizing car prises and improve the profit of the company

# %% [markdown]
# **Collecting Data**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:\Innomatics_Datasets\Car Brand.csv")
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.memory_usage().sum()/1024/1024
# Out:
# 1.4544715881347656

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %% [markdown]
# df.rename({old:new})

# %%
#Changing the column name
df.rename({'Engine Fuel Type':'Fuel Type',
          'Engine HP':'Horse Power','Engine Cylinders':'Cylinders'},inplace = True,axis =1)
df
# Out:
#           Make       Model  Year                       Fuel Type  Horse Power  \
# 0          BMW  1 Series M  2011     premium unleaded (required)        335.0
# 1          BMW    1 Series  2011     premium unleaded (required)        300.0
# 2          BMW    1 Series  2011     premium unleaded (required)        300.0
# 3          BMW    1 Series  2011     premium unleaded (required)        230.0
# 4          BMW    1 Series  2011     premium unleaded (required)        230.0
# ...        ...         ...   ...                             ...          ...
# 11909    Acura         ZDX  2012     premium unleaded (required)        300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)        300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)        300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)        300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded        221.0
#
# ...

# %% [markdown]
# **Basic Data Analysis**

# %%
df['Make'].nunique() #No of car brands
# Out:
# 48

# %%
df['Make'].value_counts().nlargest(5).index #Top 5 brands with more no of cars
# Out:
# Index(['Chevrolet', 'Ford', 'Volkswagen', 'Toyota', 'Dodge'], dtype='object', name='Make')

# %%
df['Year'].value_counts().nlargest(5).index #year having more no of cars manufactured
# Out:
# Index([2015, 2016, 2017, 2014, 2012], dtype='int64', name='Year')

# %%
df.rename({'MSRP':'Price'},inplace = True,axis =1)

# %%
df['Price'].max()
# Out:
# 2065902

# %%
df['Price'].min()
# Out:
# 2000

# %%
df.groupby(by = 'Horse Power')['city mpg'].mean()
# Out:
# Horse Power
# 55.0      33.000000
# 62.0      36.000000
# 63.0      29.777778
# 66.0      53.000000
# 73.0      26.222222
#             ...
# 707.0     13.000000
# 720.0     10.500000
# 731.0     11.000000
# 750.0     11.000000
# 1001.0     8.000000
# Name: city mpg, Length: 357, dtype: float64

# %%
#Analyze each  and every column

# %% [markdown]
# **Data Cleaning**

# %%
df.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Fuel Type               3
# Horse Power            69
# Cylinders              30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# Price                   0
# dtype: int64

# %%
df[df['Fuel Type'].isna()]
# Out:
#          Make   Model  Year Fuel Type  Horse Power  Cylinders  \
# 11321  Suzuki  Verona  2004       NaN        155.0        6.0
# 11322  Suzuki  Verona  2004       NaN        155.0        6.0
# 11323  Suzuki  Verona  2004       NaN        155.0        6.0
#
#       Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# 11322         AUTOMATIC  front wheel drive              4.0             NaN
# 11323         AUTOMATIC  front wheel drive              4.0             NaN
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity  Price
# 11321      Midsize         Sedan           25        17         481  17199
# 11322      Midsize         Sedan           25        17         481  20199
# 11323      Midsize         Sedan           25        17         481  18499

# %%
df['Fuel Type'].unique()
# Out:
# array(['premium unleaded (required)', 'regular unleaded',
#        'premium unleaded (recommended)', 'flex-fuel (unleaded/E85)',
#        'diesel', 'electric',
#        'flex-fuel (premium unleaded recommended/E85)', 'natural gas',
#        'flex-fuel (premium unleaded required/E85)',
#        'flex-fuel (unleaded/natural gas)', nan], dtype=object)

# %%
df['Fuel Type'].fillna('flex-fuel(unleaded/natural gas)',inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15352\1338506443.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fuel Type'].fillna('flex-fuel(unleaded/natural gas)',inplace = True)

# %%
df['Fuel Type'].isna().sum()
# Out:
# 0

# %%
df[df['Horse Power'].isna()]
# Out:
#          Make        Model  Year                       Fuel Type  Horse Power  \
# 539      FIAT         500e  2015                        electric          NaN
# 540      FIAT         500e  2016                        electric          NaN
# 541      FIAT         500e  2017                        electric          NaN
# 2905  Lincoln  Continental  2017  premium unleaded (recommended)          NaN
# 2906  Lincoln  Continental  2017  premium unleaded (recommended)          NaN
# ...       ...          ...   ...                             ...          ...
# 9850      Kia      Soul EV  2015                        electric          NaN
# 9851      Kia      Soul EV  2015                        electric          NaN
# 9852      Kia      Soul EV  2016                        electric          NaN
# 9853      Kia      Soul EV  2016                        electric          NaN
# 9854      Kia      Soul EV  2016                        electric          NaN
#
# ...

# %%
df.groupby(by = 'Make')['Horse Power'].transform(lambda x:x.fillna(x.mean()))
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Horse Power, Length: 11914, dtype: float64

# %%
df['Horse Power'].fillna(df['Horse Power'].mean(),inplace = True) #for tesla as there is no value so mean couldnit apply in the previous step
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15352\2505916148.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Horse Power'].fillna(df['Horse Power'].mean(),inplace = True) #for tesla as there is no value so mean couldnit apply in the previous step

# %%
df.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Fuel Type               0
# Horse Power             0
# Cylinders              30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# Price                   0
# dtype: int64

# %%
df[df['Cylinders'].isna()]
# Out:
#             Make    Model  Year                    Fuel Type  Horse Power  \
# 1983   Chevrolet  Bolt EV  2017                     electric    200.00000
# 1984   Chevrolet  Bolt EV  2017                     electric    200.00000
# 3716  Volkswagen   e-Golf  2015                     electric    115.00000
# 3717  Volkswagen   e-Golf  2015                     electric    115.00000
# 3718  Volkswagen   e-Golf  2016                     electric    115.00000
# 3719  Volkswagen   e-Golf  2016                     electric    115.00000
# 5778  Mitsubishi   i-MiEV  2014                     electric    249.38607
# 5779  Mitsubishi   i-MiEV  2016                     electric     66.00000
# 5780  Mitsubishi   i-MiEV  2017                     electric     66.00000
# 8373      Toyota  RAV4 EV  2012                     electric    154.00000
# 8695       Mazda     RX-7  1993             regular unleaded    255.00000
# 8696       Mazda     RX-7  1994             regular unleaded    255.00000
# ...

# %%
df['Cylinders'] = df.groupby(by = 'Make')['Cylinders'].transform(lambda x:x.fillna(x.median()))

# %%
df['Cylinders'].isna().sum()
# Out:
# 0

# %%
df[df['Number of Doors'].isna()]
# Out:
#          Make    Model  Year                    Fuel Type  Horse Power  \
# 4666  Ferrari       FF  2013  premium unleaded (required)    651.00000
# 6930    Tesla  Model S  2016                     electric    249.38607
# 6931    Tesla  Model S  2016                     electric    249.38607
# 6932    Tesla  Model S  2016                     electric    249.38607
# 6933    Tesla  Model S  2016                     electric    249.38607
# 6934    Tesla  Model S  2016                     electric    249.38607
#
#       Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 4666       12.0  AUTOMATED_MANUAL   all wheel drive              NaN
# 6930        0.0      DIRECT_DRIVE   all wheel drive              NaN
# 6931        0.0      DIRECT_DRIVE   all wheel drive              NaN
# 6932        0.0      DIRECT_DRIVE   all wheel drive              NaN
# 6933        0.0      DIRECT_DRIVE  rear wheel drive              NaN
# ...

# %%
df['Number of Doors'].fillna(4,inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15352\800459462.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Number of Doors'].fillna(4,inplace = True)

# %%
df.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Fuel Type               0
# Horse Power             0
# Cylinders               0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         0
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# Price                   0
# dtype: int64

# %%
df[df['Market Category'].isna()]
# Out:
#          Make     Model  Year                       Fuel Type  Horse Power  \
# 87     Nissan     200SX  1996                regular unleaded        115.0
# 88     Nissan     200SX  1996                regular unleaded        115.0
# 91     Nissan     200SX  1997                regular unleaded        115.0
# 92     Nissan     200SX  1997                regular unleaded        115.0
# 93     Nissan     200SX  1998                regular unleaded        115.0
# ...       ...       ...   ...                             ...          ...
# 11794  Subaru        XT  1991                regular unleaded        145.0
# 11809  Toyota  Yaris iA  2017                regular unleaded        106.0
# 11810  Toyota  Yaris iA  2017                regular unleaded        106.0
# 11867     GMC     Yukon  2015  premium unleaded (recommended)        420.0
# 11868     GMC     Yukon  2015  premium unleaded (recommended)        420.0
#
# ...

# %%
df['Market Category'].fillna(df['Market Category'].mode()[0],inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15352\25287349.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Market Category'].fillna(df['Market Category'].mode()[0],inplace = True)

# %%
df.isna().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Fuel Type            0
# Horse Power          0
# Cylinders            0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# Price                0
# dtype: int64

# %% [markdown]
# **Duplicates**

# %%
df.duplicated().sum()
# Out:
# 715

# %%
df.drop_duplicates(inplace = True,ignore_index = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Outliers analysis**

# %%
df.select_dtypes(exclude = 'object')
# Out:
#        Year  Horse Power  Cylinders  Number of Doors  highway MPG  city mpg  \
# 0      2011        335.0        6.0              2.0           26        19
# 1      2011        300.0        6.0              2.0           28        19
# 2      2011        300.0        6.0              2.0           28        20
# 3      2011        230.0        6.0              2.0           28        18
# 4      2011        230.0        6.0              2.0           28        18
# ...     ...          ...        ...              ...          ...       ...
# 11194  2012        300.0        6.0              4.0           23        16
# 11195  2012        300.0        6.0              4.0           23        16
# 11196  2012        300.0        6.0              4.0           23        16
# 11197  2013        300.0        6.0              4.0           23        16
# 11198  2006        221.0        6.0              4.0           26        17
#
#        Popularity  Price
# 0            3916  46135
# ...

# %%
df['Horse Power'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Number of Doors'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df[df['highway MPG']>300]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Fuel Type, Horse Power, Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, Price]
# Index: []

# %%
q1 = df['highway MPG'].quantile(0.25)
q3 = df['highway MPG'].quantile(0.75)
iqr = q3-q1
ll= max(df['highway MPG'].min(),q1-1.5*iqr)
ul = min(df['highway MPG'].max(),q3+1.5*iqr)

# %%
df['highway MPG'] = df['highway MPG'].clip(ll,ul)

# %%
df[df['highway MPG']>300]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Fuel Type, Horse Power, Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, Price]
# Index: []

# %%
df[df['city mpg']>500]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Fuel Type, Horse Power, Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, Price]
# Index: []

# %%
df[df['Price']>1000000]
# Out:
#               Make        Model  Year                    Fuel Type  \
# 6000       Maybach    Landaulet  2011  premium unleaded (required)
# 6001       Maybach    Landaulet  2012  premium unleaded (required)
# 7973   Lamborghini     Reventon  2008  premium unleaded (required)
# 10661      Bugatti  Veyron 16.4  2008  premium unleaded (required)
# 10662      Bugatti  Veyron 16.4  2008  premium unleaded (required)
# 10663      Bugatti  Veyron 16.4  2009  premium unleaded (required)
#
#        Horse Power  Cylinders Transmission Type     Driven_Wheels  \
# 6000         620.0       12.0         AUTOMATIC  rear wheel drive
# 6001         620.0       12.0         AUTOMATIC  rear wheel drive
# 7973         650.0       12.0  AUTOMATED_MANUAL   all wheel drive
# 10661       1001.0       16.0  AUTOMATED_MANUAL   all wheel drive
# 10662       1001.0       16.0  AUTOMATED_MANUAL   all wheel drive
# 10663       1001.0       16.0  AUTOMATED_MANUAL   all wheel drive
#
# ...

# %% [markdown]
# ***Data Visualization**

# %% [markdown]
# **Univariate Analysis**

# %%
import plotly.express as px

# %%
px.histogram(df,x ='Horse Power')

# %%
px.histogram(df,x ='Price')

# %%
px.histogram(df,x ='Cylinders')

# %%
df['Make'].value_counts().nlargest(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Make'>

# %%
df['Make'].value_counts().nlargest(10).plot(kind = 'pie',autopct = '%.1f%%') #Top 10 cars
# Out:
# <Axes: ylabel='count'>

# %%
df['Make'].value_counts().nsmallest(5).plot(kind = 'pie',autopct = '%.1f%%') #Least 5 cars
# Out:
# <Axes: ylabel='count'>

# %%
df['Year'].value_counts().plot(kind ='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
df['Fuel Type'].value_counts().plot(kind ='bar')
# Out:
# <Axes: xlabel='Fuel Type'>

# %%
df['Transmission Type'].value_counts().plot(kind ='bar')
# Out:
# <Axes: xlabel='Transmission Type'>

# %%
df['Vehicle Size'].value_counts().plot(kind = 'pie',autopct = '%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Vehicle Style'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Vehicle Style'>

# %%
df['Vehicle Style'].value_counts().nlargest(3).plot(kind = 'pie',autopct = '%.1f%%') #Top 10 cars
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Bi Variate Analysis**

# %%
df.select_dtypes(exclude = 'object')
# Out:
#        Year  Horse Power  Cylinders  Number of Doors  highway MPG  city mpg  \
# 0      2011        335.0        6.0              2.0           26        19
# 1      2011        300.0        6.0              2.0           28        19
# 2      2011        300.0        6.0              2.0           28        20
# 3      2011        230.0        6.0              2.0           28        18
# 4      2011        230.0        6.0              2.0           28        18
# ...     ...          ...        ...              ...          ...       ...
# 11194  2012        300.0        6.0              4.0           23        16
# 11195  2012        300.0        6.0              4.0           23        16
# 11196  2012        300.0        6.0              4.0           23        16
# 11197  2013        300.0        6.0              4.0           23        16
# 11198  2006        221.0        6.0              4.0           26        17
#
#        Popularity  Price
# 0            3916  46135
# ...

# %%
sns.scatterplot(data = df, x = 'Horse Power',y = 'Price')
# Out:
# <Axes: xlabel='Horse Power', ylabel='Price'>

# %%
sns.scatterplot(data = df, x = 'Cylinders',y = 'Price')
# Out:
# <Axes: xlabel='Cylinders', ylabel='Price'>

# %%
sns.scatterplot(data = df, x = 'Number of Doors',y = 'Price')
# Out:
# <Axes: xlabel='Number of Doors', ylabel='Price'>

# %%
sns.scatterplot(data = df, x = 'highway MPG',y = 'Price')
# Out:
# <Axes: xlabel='highway MPG', ylabel='Price'>

# %% [markdown]
# **Category and Numerical**

# %%
sns.lineplot(data = df,x = 'Year',y = 'Price')
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
sns.barplot(data= df,x = 'Make', y = 'highway MPG')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data= df,x = 'Make', y = 'highway MPG',estimator = 'mean')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data=df,x = 'Vehicle Size',y = 'city mpg')
# Out:
# <Axes: xlabel='Vehicle Size', ylabel='city mpg'>

# %% [markdown]
# **MultiVariate analysis**

# %%
sns.heatmap(df.corr(numeric_only=True),annot =True)
# Out:
# <Axes: >
